# %%
import sys
sys.path.append("/workspace/build")

import openbnsl
dir(openbnsl)

print(openbnsl.myadd(1, 2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 7
#       4 import openbnsl
#       5 dir(openbnsl)
# ----> 7 print(openbnsl.myadd(1, 2))
#
# AttributeError: module 'openbnsl' has no attribute 'myadd'

# %%
import numpy as np

a = np.array(
    [[1, 2], 
     [3, 4]]
)
b = np.array(
    [[5, 6], 
     [7, 8]]
)

c_naive = openbnsl.matmul_naive(a, b)
c_openmp = openbnsl.matmul_openmp(a, b)
print(c_naive)

print(openbnsl.myadd(1, 2))
# Out:
# [[19. 22.]
#  [43. 50.]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 16
#      13 c_openmp = openbnsl.matmul_openmp(a, b)
#      14 print(c_naive)
# ---> 16 print(openbnsl.myadd(1, 2))
#
# AttributeError: module 'openbnsl' has no attribute 'myadd'

# %%
# Out:
# [[19. 22.]
#  [43. 50.]]
